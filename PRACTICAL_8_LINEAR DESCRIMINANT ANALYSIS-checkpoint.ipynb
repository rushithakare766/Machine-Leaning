# %% [markdown]
# # Essential Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
df = pd.read_csv(r"C:\Users\91766\Downloads\Heart.csv")
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.shape
# Out:
# (303, 15)

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
#        'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
dummy_features = pd.get_dummies(df['ChestPain'],drop_first=True)

# %%
dummy_features
# Out:
#      nonanginal  nontypical  typical
# 0             0           0        1
# 1             0           0        0
# 2             0           0        0
# 3             1           0        0
# 4             0           1        0
# ..          ...         ...      ...
# 298           0           0        1
# 299           0           0        0
# 300           0           0        0
# 301           0           1        0
# 302           1           0        0
#
# [303 rows x 3 columns]

# %%
# Creating a dummy variable for some of the categorical variables and dropping the first one.
dummy1 = pd.get_dummies(df[['Sex', 'ChestPain','RestECG','ExAng','Slope']], drop_first=True)

# Adding the results to the master dataframe
final_data = pd.concat([df, dummy1], axis=1)

# %%
# Adding the results to the master dataframe
final_data = pd.concat([df, dummy1], axis=1)

# %%
final_data.head()
# Out:
#    Unnamed: 0  Age Sex     ChestPain  RestBP  Chol  Fbs RestECG  MaxHR  ExAng  \
# 0           1   63   1       typical     145   233    1       2    150      0
# 1           2   67   1  asymptomatic     160   286    0       2    108      1
# 2           3   67   1  asymptomatic     120   229    0       2    129      1
# 3           4   37   1    nonanginal     130   250    0       0    187      0
# 4           5   41   0    nontypical     130   204    0       2    172      0
#
#    ...   Ca        Thal  AHD Sex RestECG  ExAng  Slope  ChestPain_nonanginal  \
# 0  ...  0.0       fixed   No   1       2      0      3                     0
# 1  ...  3.0      normal  Yes   1       2      1      2                     0
# 2  ...  2.0  reversable  Yes   1       2      1      2                     0
# 3  ...  0.0      normal   No   1       0      0      3                     1
# 4  ...  0.0      normal   No   0       2      0      1                     0
#
# ...

# %%
final_data = final_data.drop(['Sex', 'ChestPain','RestECG','ExAng','Slope'],1)

# %%
final_data.shape
# Out:
# (303, 13)

# %%
final_data.head()
# Out:
#    Unnamed: 0  Age  RestBP  Chol  Fbs  MaxHR  Oldpeak   Ca        Thal  AHD  \
# 0           1   63     145   233    1    150      2.3  0.0       fixed   No
# 1           2   67     160   286    0    108      1.5  3.0      normal  Yes
# 2           3   67     120   229    0    129      2.6  2.0  reversable  Yes
# 3           4   37     130   250    0    187      3.5  0.0      normal   No
# 4           5   41     130   204    0    172      1.4  0.0      normal   No
#
#    ChestPain_nonanginal  ChestPain_nontypical  ChestPain_typical
# 0                     0                     0                  1
# 1                     0                     0                  0
# 2                     0                     0                  0
# 3                     1                     0                  0
# 4                     0                     1                  0

# %% [raw]
# Assigning values to input output vector

# %%
x_data = final_data.drop('Ca',1)
y_data = final_data['Ca']

# %%
X = x_data.to_numpy()
y = y_data.to_numpy()
